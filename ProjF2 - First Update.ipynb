# %% [markdown]
# ## ProjF2 - Data Exploration
#
# Use this document as a template to provide some exploratory analysis of your data similar to the one in ProjC1. You are welcome to go in as much depth as needed.
#
# Make sure you keep the sections specified in this template, but you are welcome to add more cells with your code or explanation as needed.

# %% [markdown]
# **Dataset Description**
# - age : 5-years gap
# - height(cm)
# - weight(kg)
# - waist(cm) : Waist circumference length
# - eyesight(left)
# - eyesight(right)
# - hearing(left)
# - hearing(right)
# - systolic : Blood pressure
# - relaxation : Blood pressure
# - fasting blood sugar
# - Cholesterol : total
# - triglyceride
# - HDL : cholesterol type
# - LDL : cholesterol type
# - hemoglobin
# - Urine protein
# - serum creatinine
# - AST : glutamic oxaloacetic transaminase type
# - ALT : glutamic oxaloacetic transaminase type
# - Gtp : γ-GTP
# - dental caries
# - smoking

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### 1. Load and Visualize Data
#
# Let's start by loading your entire dataset or a sample if it is a larger dataset.

# %%
### YOUR CODE HERE
train_df = pd.read_csv("datasets/train_dataset.csv")
# test_df = pd.read_csv("datasets/test_dataset.csv")

# %%
# print("Size of datasets\ntrain_df: {0} \ntest_df: {1}".format(len(train_df), len(test_df)))
len(train_df)
# Out:
# 38984

# %%
train_df.describe()
# Out:
#                 age    height(cm)    weight(kg)     waist(cm)  eyesight(left)  \
# count  38984.000000  38984.000000  38984.000000  38984.000000    38984.000000
# mean      44.127591    164.689488     65.938718     82.062115        1.014955
# std       12.063564      9.187507     12.896581      9.326798        0.498527
# min       20.000000    130.000000     30.000000     51.000000        0.100000
# 25%       40.000000    160.000000     55.000000     76.000000        0.800000
# 50%       40.000000    165.000000     65.000000     82.000000        1.000000
# 75%       55.000000    170.000000     75.000000     88.000000        1.200000
# max       85.000000    190.000000    135.000000    129.000000        9.900000
#
#        eyesight(right)  hearing(left)  hearing(right)      systolic  \
# count     38984.000000   38984.000000    38984.000000  38984.000000
# mean          1.008768       1.025369        1.026190    121.475631
# ...

# %%
train_df.hist(bins=10, figsize=(10, 8))
plt.suptitle('Histograms of Features', x=0.5, y=1.02, fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# Provide some visualization of the data. For example,
# - If your data is time series, you can plot a sequence and the response or label.
# - If tabular data, you can plot histograms of the data.
# - If working with image recognition or segmentation, you can show an image and the corresponding output.
# - If it is a video that you are processing, just show screenshots.
# - If doing something with reinforcement learning, you can provide samples of the simulation environment used.

# %%
### YOUR CODE HERE
plt.figure(figsize=(10, 5))
sns.countplot(x='smoking', data=train_df)
plt.title('Count of Smoking Status')
plt.show()

# %% [markdown]
# ### 2. Compute Some Statistics from your Data
#
# First, extract some characterisitics about the input (e.g., image size, means and standard deviation of values, sample frequency).

# %%
### YOUR CODE HERE
numerical_stats = train_df.describe()

print("Numerical Features Statistics:")
print(numerical_stats)
# Out:
# Numerical Features Statistics:
#                 age    height(cm)    weight(kg)     waist(cm)  eyesight(left)  \
# count  38984.000000  38984.000000  38984.000000  38984.000000    38984.000000
# mean      44.127591    164.689488     65.938718     82.062115        1.014955
# std       12.063564      9.187507     12.896581      9.326798        0.498527
# min       20.000000    130.000000     30.000000     51.000000        0.100000
# 25%       40.000000    160.000000     55.000000     76.000000        0.800000
# 50%       40.000000    165.000000     65.000000     82.000000        1.000000
# 75%       55.000000    170.000000     75.000000     88.000000        1.200000
# max       85.000000    190.000000    135.000000    129.000000        9.900000
#
#        eyesight(right)  hearing(left)  hearing(right)      systolic  \
# count     38984.000000   38984.000000    38984.000000  38984.000000
# mean          1.008768       1.025369        1.026190    121.475631
# ...

# %% [markdown]
# Next, provide some characteristics about your output (e.g., histograms, spatial distribution of bounding boxes in the case of object detection, etc.). In the case of cases such as tasks such as reinforcement learning, you can provide details about the desired output and rewards used. You can show some correlations between inputs and outputs if possible.

# %%
corr = train_df.corr()

plt.figure(figsize=(20, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=.5, fmt=".2f")
plt.title('Correlation Heatmap', fontsize=16)
plt.show()

# %% [markdown]
# Interestingly, the most correlated factors are waist(cm) and weight(kg) at 0.82 correlation. Most pairs of variables have correlation between -.2 and .2

# %% [markdown]
# ### 3. Comment on Your Data
#
# Answer these questions as appropriate?
# - Is your data balanced?
# - Are there disparities in your input data? Does it show some specific patterns?

# %%
selected_columns = train_df.select_dtypes(include=['float', 'int']).columns[:-2]

# %%
plt.figure(figsize=(5, 20))
for i, column in enumerate(selected_columns):
    plt.subplot((len(train_df.columns) // 3) + 1, 3, i + 1)
    sns.boxplot(y=train_df[column])
    plt.title(column)
    plt.tight_layout()

plt.show()

# %% [markdown]
# - Most smokers are between ages 40 and 60.
# - For Cholesterol, we see significant number of outliers on the right side, skewing the data to the right.
# - There are also some questionable values such as LDL above 200. This may be due to faulty sensor, invalid input, etc. We will discuss what to do later.

# %%
# non-smokers
non_smokers = train_df[train_df['smoking'] == 0]

# smokers
smokers = train_df[train_df['smoking'] == 1]

# %%
# non-smokers boxplots
plt.figure(figsize=(5, 20))
for i, column in enumerate(selected_columns):
    plt.subplot((len(non_smokers.columns) // 3) + 1, 3, i + 1)
    sns.boxplot(y=non_smokers[column])
    plt.title(column)
    plt.tight_layout()

plt.show()

# %%
# smokers boxplots
plt.figure(figsize=(5, 20))
for i, column in enumerate(selected_columns):
    plt.subplot((len(smokers.columns) // 3) + 1, 3, i + 1)
    sns.boxplot(y=smokers[column])
    plt.title(column)
    plt.tight_layout()

plt.show()

# %% [markdown]
# ### Common outliers
# Surprisingly, the outliers for factors such as LDL are existent for both the smoking and non-smoking demographics. Perhaps, there is confounding variable?
